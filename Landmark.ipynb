# %%
import dlib
import cv2
import imutils
import matplotlib.pyplot as plt
from imutils import face_utils
#from google.colab.patches import cv2_imshow # usar no colab

# %%
detector_faces = dlib.get_frontal_face_detector()
predictor_pontos = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
imagem_entrada = cv2.imread("IMG_5294.JPG")

# %%
image_rgb = cv2.cvtColor(imagem_entrada, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')  # Opcional: desativa os eixos
plt.show()

# %%
imagem_cinza = cv2.cvtColor(imagem_entrada, cv2.COLOR_BGR2GRAY)

# %%
image_rgb = cv2.cvtColor(imagem_cinza, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')  # Opcional: desativa os eixos
plt.show()

# %%
rects = detector_faces(imagem_cinza)

# %%
rects
# Out:
# rectangles[[(472, 113) (687, 328)]]

# %%
for (i, rect) in enumerate(rects):
    pontos_referencia = predictor_pontos(imagem_cinza, rect)
    pontos_referencia = face_utils.shape_to_np(pontos_referencia)


    (x, y, w, h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(imagem_entrada, (x, y), (x+w, y+h), (0, 255, 0), 2)

    for (x, y) in pontos_referencia:
        cv2.circle(imagem_entrada, (x, y), 1, (255, 255, 0), -1)

    #cv2_imshow(imagem_entrada) # usar no colab
    image_rgb = cv2.cvtColor(imagem_entrada, cv2.COLOR_BGR2RGB)
    plt.imshow(image_rgb)
    plt.axis('off')  # Opcional: desativa os eixos
    plt.show()

# %%
pontos_referencia.shape
# Out:
# (68, 2)

# %%
from imutils.video import VideoStream

# %%
'''
captura = cv2.VideoCapture(0)  # 0 para usar a webcam padrão, ou forneça o índice da webcam específica

while True:
    ret, frame = captura.read()

    # Exiba o frame capturado
    cv2.imshow('Webcam', frame)

    # Pare o loop quando pressionar a tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Libere os recursos
captura.release()
cv2.destroyAllWindows()
'''
# Out:
# "\ncaptura = cv2.VideoCapture(0)  # 0 para usar a webcam padrão, ou forneça o índice da webcam específica\n\nwhile True:\n    ret, frame = captura.read()\n\n    # Exiba o frame capturado\n    cv2.imshow('Webcam', frame)\n\n    # Pare o loop quando pressionar a tecla 'q'\n    if cv2.waitKey(1) & 0xFF == ord('q'):\n        break\n\n# Libere os recursos\ncaptura.release()\ncv2.destroyAllWindows()\n"

# %%
'''
from IPython.display import Image

captura = cv2.VideoCapture(0)  # 0 para usar a webcam padrão, ou forneça o índice da webcam específica

while True:
    ret, frame = captura.read()

    # Converta o frame para o formato JPEG
    ret, jpeg = cv2.imencode('.jpg', frame)

    # Exiba o frame usando a função display() do IPython
    display(Image(data=jpeg.tobytes(), format='jpeg'))

    # Pare o loop quando pressionar a tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Libere os recursos
captura.release()
cv2.destroyAllWindows()
'''
# Out:
# "\nfrom IPython.display import Image\n\ncaptura = cv2.VideoCapture(0)  # 0 para usar a webcam padrão, ou forneça o índice da webcam específica\n\nwhile True:\n    ret, frame = captura.read()\n\n    # Converta o frame para o formato JPEG\n    ret, jpeg = cv2.imencode('.jpg', frame)\n\n    # Exiba o frame usando a função display() do IPython\n    display(Image(data=jpeg.tobytes(), format='jpeg'))\n\n    # Pare o loop quando pressionar a tecla 'q'\n    if cv2.waitKey(1) & 0xFF == ord('q'):\n        break\n\n# Libere os recursos\ncaptura.release()\ncv2.destroyAllWindows()\n"

# %%
'''
from IPython.display import display
from ipywidgets import Video
captura = cv2.VideoCapture(0)  # 0 para usar a webcam padrão, ou forneça o índice da webcam específica

video_widget = Video()

while True:
    ret, frame = captura.read()

    # Atualiza o widget de vídeo com o novo frame
    video_widget.value = cv2.imencode('.jpg', frame)[1].tobytes()

    # Exibe o widget de vídeo
    display(video_widget)

    # Pare o loop quando pressionar a tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Libere os recursos
captura.release()
cv2.destroyAllWindows()
'''
# Out:
# "\nfrom IPython.display import display\nfrom ipywidgets import Video\ncaptura = cv2.VideoCapture(0)  # 0 para usar a webcam padrão, ou forneça o índice da webcam específica\n\nvideo_widget = Video()\n\nwhile True:\n    ret, frame = captura.read()\n\n    # Atualiza o widget de vídeo com o novo frame\n    video_widget.value = cv2.imencode('.jpg', frame)[1].tobytes()\n\n    # Exibe o widget de vídeo\n    display(video_widget)\n\n    # Pare o loop quando pressionar a tecla 'q'\n    if cv2.waitKey(1) & 0xFF == ord('q'):\n        break\n\n# Libere os recursos\ncaptura.release()\ncv2.destroyAllWindows()\n"
